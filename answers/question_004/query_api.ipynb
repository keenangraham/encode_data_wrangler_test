# %% [markdown]
# # Answer 4:

# %%
import numpy as np
import pandas as pd
import requests

# %%
def query_encode_api(kind, assay, month):
    """
    Return accession, biosample, protein target, and number
    of replicates of each ENCODE entry given query constraints. 
    """
    
    results = []
    url = 'https://www.encodeproject.org/search/'\
            '?type={0}&assay_title={1}&month_released={2}'\
            '&frame=embedded&limit=all&format=json'.format(kind,
                                                       assay,
                                                       month.replace(" ", "+"))
    r = requests.get(url)
    r = r.json()["@graph"]
    for entry in r:
        results.append({
                "accession": entry["accession"],
                "biosample_summary": entry["biosample_summary"],
                "biosample_type": entry["biosample_type"],
                "protein_target": entry["target"]["label"],
                "replicate_number": len(entry["replicates"])
            })
            
    return results

# %% [markdown]
# #### Query the ENCODE API for all ChIP-seq assays released in August 2012

# %%
results = pd.DataFrame(query_encode_api(kind="Experiment", assay="ChIP-seq", month="August, 2012"))

# %%
results
# Out:
#        accession                                  biosample_summary  \
# 0    ENCSR000ESE                                DBA/2 MEL cell line
# 1    ENCSR000DMY                                    medulloblastoma
# 2    ENCSR000EDR                                              HepG2
# 3    ENCSR000DLL                      heart female adult (20 years)
# 4    ENCSR000DML                           MCF-7 derived from MCF-7
# 5    ENCSR000DYU                                            GM12878
# 6    ENCSR000DHB             129 G1E-ER4 treated with 17β-estradiol
# 7    ENCSR000ASS                          A549 treated with ethanol
# 8    ENCSR000DNB                                               A549
# 9    ENCSR000DNI  spleen female adult (20 years) and female adul...
# 10   ENCSR000ERX                                         129 ES-E14
# 11   ENCSR000ESN                                DBA/2 MEL cell line
# 12   ENCSR000DYC                                               A549
# 13   ENCSR000DHA             129 G1E-ER4 treated with 17β-estradiol
# 14   ENCSR000DYS                                            GM12878
# 15   ENCSR000EHY                                            SK-N-SH
# 16   ENCSR000DGX             129 G1E-ER4 treated with 17β-estradiol
# 17   ENCSR000EQU                          B10.H-2aH-4bp/Wts CH12.LX
# 18   ENCSR000AUA                                               K562
# 19   ENCSR000EDU                                              HepG2
# 20   ENCSR000DYT                                            GM12878
# 21   ENCSR000DHC                                        129 G1E-ER4
# 22   ENCSR000DKZ                                            GM13976
# 23   ENCSR000DKQ                                            GM10248
# 24   ENCSR000AEA  DBA/2 MEL cell line treated with dimethyl sulf...
# 25   ENCSR000ATN                      CD14-positive monocyte female
# 26   ENCSR000ASQ                      CD14-positive monocyte female
# 27   ENCSR000AUK                          A549 treated with ethanol
# 28   ENCSR000EFD                     IMR-90 female fetal (16 weeks)
# 29   ENCSR000DYD                                               A549
# ..           ...                                                ...
# 171  ENCSR000EFT                                               K562
# 172  ENCSR000ASK                      CD14-positive monocyte female
# 173  ENCSR000ATX                                               K562
# 174  ENCSR000DMJ                           MCF-7 derived from MCF-7
# 175  ENCSR000ASJ                      CD14-positive monocyte female
# 176  ENCSR000EFC                     IMR-90 female fetal (16 weeks)
# 177  ENCSR000DHE              CD-1 megakaryocyte embryo (14.5 days)
# 178  ENCSR000DGY             129 G1E-ER4 treated with 17β-estradiol
# 179  ENCSR000ASL                      CD14-positive monocyte female
# 180  ENCSR000AUZ                     B cell female adult (27 years)
# 181  ENCSR000AUB                                               K562
# 182  ENCSR000AVH                    A549 treated with dexamethasone
# 183  ENCSR000AVJ                     B cell female adult (27 years)
# 184  ENCSR000DHD              CD-1 megakaryocyte embryo (14.5 days)
# 185  ENCSR000EQP                          B10.H-2aH-4bp/Wts CH12.LX
# 186  ENCSR000DME  LNCaP clone FGC treated with 17β-hydroxy-17-me...
# 187  ENCSR000EQO                          B10.H-2aH-4bp/Wts CH12.LX
# 188  ENCSR000ASO                      CD14-positive monocyte female
# 189  ENCSR000DMA                                               K562
# 190  ENCSR000DJB                                            129 G1E
# 191  ENCSR000DMC  kidney male adult (22 years) and male adult (2...
# 192  ENCSR000AUS                                            H1-hESC
# 193  ENCSR000DMN                           MCF-7 derived from MCF-7
# 194  ENCSR000AUG                    A549 treated with dexamethasone
# 195  ENCSR000DGS             129 G1E-ER4 treated with 17β-estradiol
# 196  ENCSR000EFS                                               K562
# 197  ENCSR000ASM                      CD14-positive monocyte female
# 198  ENCSR000ATV                                               K562
# 199  ENCSR000AUP                     B cell female adult (27 years)
# 200  ENCSR000ADT                                DBA/2 MEL cell line
#
#              biosample_type    protein_target  replicate_number
# 0    immortalized cell line             ZMIZ1                 2
# 1    immortalized cell line              CTCF                 2
# 2    immortalized cell line  goat-IgG-control                 2
# 3                    tissue           Control                 1
# 4    immortalized cell line              CTCF                 2
# 5    immortalized cell line            SREBF1                 2
# 6    immortalized cell line             GATA1                 1
# 7    immortalized cell line           Control                 2
# 8    immortalized cell line           Control                 1
# 9                    tissue              CTCF                 2
# 10                stem cell             HCFC1                 2
# 11   immortalized cell line              CHD1                 2
# 12   immortalized cell line               MYC                 2
# 13   immortalized cell line             GATA1                 1
# 14   immortalized cell line              JUND                 2
# 15   immortalized cell line              RFX5                 2
# 16   immortalized cell line             GATA1                 1
# 17   immortalized cell line             KAT2A                 2
# 18   immortalized cell line              RNF2                 2
# 19   immortalized cell line              MXI1                 3
# 20   immortalized cell line            SREBF2                 2
# 21   immortalized cell line             GATA1                 1
# 22   immortalized cell line              CTCF                 2
# 23   immortalized cell line           Control                 1
# 24   immortalized cell line           H3K4me3                 2
# 25             primary cell              CTCF                 2
# 26             primary cell          H4K20me1                 2
# 27   immortalized cell line          H3K27me3                 2
# 28             primary cell              RFX5                 2
# 29   immortalized cell line              CTCF                 2
# ..                      ...               ...               ...
# 171  immortalized cell line             GATA1                 2
# 172            primary cell          H3K27me3                 2
# 173  immortalized cell line             KDM1A                 4
# 174  immortalized cell line               MYC                 2
# 175            primary cell           H3K27ac                 2
# 176            primary cell              CHD1                 2
# 177            primary cell              TAL1                 4
# 178  immortalized cell line             GATA1                 1
# 179            primary cell          H3K36me3                 2
# 180            primary cell              EZH2                 2
# 181  immortalized cell line             SIRT6                 1
# 182  immortalized cell line           H3K4me1                 2
# 183            primary cell          H4K20me1                 2
# 184            primary cell              FLI1                 2
# 185  immortalized cell line             ZMIZ1                 2
# 186  immortalized cell line              CTCF                 2
# 187  immortalized cell line            ZNF384                 2
# 188            primary cell          H3K79me2                 2
# 189  immortalized cell line              CTCF                 3
# 190  immortalized cell line           H3K4me1                 2
# 191                  tissue              CTCF                 3
# 192               stem cell             SIRT6                 1
# 193  immortalized cell line            POLR2A                 2
# 194  immortalized cell line             H2AFZ                 2
# 195  immortalized cell line           Control                 1
# 196  immortalized cell line               JUN                 2
# 197            primary cell           H3K4me1                 2
# 198  immortalized cell line              CBX3                 1
# 199            primary cell           H3K27ac                 2
# 200  immortalized cell line           H3K9me3                 2
#
# [201 rows x 5 columns]

# %% [markdown]
# #### Export to TSV

# %%
results.to_csv("encode_results.tsv", sep="\t")
